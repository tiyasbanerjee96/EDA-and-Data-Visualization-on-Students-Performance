# %% [markdown]
# # EDA and Data Visualization
#
# Student Performance - Marks secured by the students in various subjects

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Reading the data

# %%
d=pd.read_csv(r'C:\\Users\\TIYAS\\Downloads\\archive (17)\\StudentsPerformance.csv')

# %%
d
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# ### Cleaning the data

# %% [markdown]
# ### Drop a column

# %%
d=d.drop(columns=['race/ethnicity'])
d
# Out:
#      gender parental level of education         lunch test preparation course  \
# 0    female           bachelor's degree      standard                    none
# 1    female                some college      standard               completed
# 2    female             master's degree      standard                    none
# 3      male          associate's degree  free/reduced                    none
# 4      male                some college      standard                    none
# ..      ...                         ...           ...                     ...
# 995  female             master's degree      standard               completed
# 996    male                 high school  free/reduced                    none
# 997  female                 high school  free/reduced               completed
# 998  female                some college      standard               completed
# 999  female                some college  free/reduced                    none
#
# ...

# %% [markdown]
# ### Print top five rows of data

# %%
d.head()
# Out:
#    gender parental level of education         lunch test preparation course  \
# 0  female           bachelor's degree      standard                    none
# 1  female                some college      standard               completed
# 2  female             master's degree      standard                    none
# 3    male          associate's degree  free/reduced                    none
# 4    male                some college      standard                    none
#
#    math score  reading score  writing score
# 0          72             72             74
# 1          69             90             88
# 2          90             95             93
# 3          47             57             44
# 4          76             78             75

# %% [markdown]
# ### Print bottom five rows of data

# %%
d.tail()
# Out:
#      gender parental level of education         lunch test preparation course  \
# 995  female             master's degree      standard               completed
# 996    male                 high school  free/reduced                    none
# 997  female                 high school  free/reduced               completed
# 998  female                some college      standard               completed
# 999  female                some college  free/reduced                    none
#
#      math score  reading score  writing score
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86

# %% [markdown]
# ### To check number of rows and columns

# %%
d.shape
# Out:
# (1000, 7)

# %% [markdown]
# ### To check data types

# %%
d.dtypes
# Out:
# gender                         object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# ### To check dimensions

# %%
d.ndim
# Out:
# 2

# %% [markdown]
# ### To check the index

# %%
d.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# ### To check size of data

# %%
d.size
# Out:
# 7000

# %% [markdown]
# ### To check empty values

# %%
d.empty
# Out:
# False

# %% [markdown]
# ### To check information about data

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   parental level of education  1000 non-null   object
#  2   lunch                        1000 non-null   object
#  3   test preparation course      1000 non-null   object
#  4   math score                   1000 non-null   int64
#  5   reading score                1000 non-null   int64
#  6   writing score                1000 non-null   int64
# dtypes: int64(3), object(4)
# memory usage: 54.8+ KB

# %% [markdown]
# ### To check summary statistics

# %%
d.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
d.describe(include='all')
# Out:
#         gender parental level of education     lunch test preparation course  \
# count     1000                        1000      1000                    1000
# unique       2                           6         2                       2
# top     female                some college  standard                    none
# freq       518                         226       645                     642
# mean       NaN                         NaN       NaN                     NaN
# std        NaN                         NaN       NaN                     NaN
# min        NaN                         NaN       NaN                     NaN
# 25%        NaN                         NaN       NaN                     NaN
# 50%        NaN                         NaN       NaN                     NaN
# 75%        NaN                         NaN       NaN                     NaN
# max        NaN                         NaN       NaN                     NaN
#
# ...

# %% [markdown]
# ### To check null values

# %%
d.isna()
# Out:
#      gender  parental level of education  lunch  test preparation course  \
# 0     False                        False  False                    False
# 1     False                        False  False                    False
# 2     False                        False  False                    False
# 3     False                        False  False                    False
# 4     False                        False  False                    False
# ..      ...                          ...    ...                      ...
# 995   False                        False  False                    False
# 996   False                        False  False                    False
# 997   False                        False  False                    False
# 998   False                        False  False                    False
# 999   False                        False  False                    False
#
#      math score  reading score  writing score
# ...

# %% [markdown]
# ### To check sum of null values

# %%
d.isna().sum()
# Out:
# gender                         0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# ### To check unique values in the data

# %%
d.nunique()
# Out:
# gender                          2
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
d['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %% [markdown]
# ### To check columns

# %%
d.columns
# Out:
# Index(['gender', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(d)

# %%
sns.pairplot(d,diag_kind='kde',kind='reg')

# %%
sns.relplot(x='math score',y='reading score',hue='gender',data=d)

# %%
sns.distplot(d['math score'])

# %%
sns.catplot(x='math score',y='gender',kind='box',data=d)

# %% [markdown]
# ### To create Heatmap for checking correlation

# %%
sns.heatmap(d.corr())

# %%
sns.lineplot(data= d, x='gender',y='math score', color='blue')

# %%
sns.stripplot(x = d["gender"],y = d["math score"])
plt.title("gender VS math score")
# Out:
# Text(0.5, 1.0, 'gender VS math score')

# %%
sns.swarmplot(x = d["gender"], y = d["math score"],hue = d["gender"],s = 4)
plt.title("gender VS math score")
# Out:
# Text(0.5, 1.0, 'gender VS math score')

# %% [markdown]
# ### Conclusion
# - I have taken a data set based on Students Performance where I have done EDA and Data Visualization.
# - I have cleaned the data by dropping a column which was unnecessary for the analysis.
# - Then I have checked the number of columns, rows, data types, dimension, index, size, shape, the total information, summary      statistics etc.
# - After analysis I have done the visualiation of data by using different graphs and charts which include pairplot, line plot,
#   relplot, distplot, catplot, heatmap for correlation, stripplot and swarmplot.
